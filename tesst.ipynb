# %%
from pykrx import stock
import pandas as pd
from decimal import Decimal
import requests
from bs4 import BeautifulSoup as bs
# 더보기란의 페이지에서 외국인의 순매수량 data 읽어오기

response2 = requests.get('https://finance.daum.net/quotes/A005930#influential_investors/home').text

purchasing_html = bs(response2,'html.parser')


purchasing_html.select('html>body')
# Out:
# [<body class="finance">
#  <div id="wrap">
#  <div id="kakaoWrap">
#  <div id="wrapMinidaum"></div>
#  </div>
#  <script>
#      requirejs(["/dist/daum/app/config.js?v=1683640228"], function (common) {
#          require(["app/common/mini_daum"]);
#      });
#  </script>
#  <div class="header">
#  <div class="head_media f_clear">
#  <h1><a class="#gnb #default #service_finance" href="//finance.daum.net" id="kakaoServiceLogo"><span class="ir_wa">금융</span></a></h1>
#  <strong class="screen_out">관련서비스</strong>
#  <ul class="kakaoRelServices">
#  <li><a href="http://realestate.daum.net"><span class="ir_wa">부동산</span></a></li>
#  </ul>
#  <h2 class="screen_out">검색</h2>
#  <div class="search_news" id="boxSearch"></div>
#  <script>
#      requirejs(["/dist/daum/app/config.js?v=1683640228"], function (common) {
#          require(["app/common/search"]);
#      });
#  </script>
#  </div>
#  <div id="kakaoGnb" role="navigation">
#  <div class="inner_gnb">
# ...
